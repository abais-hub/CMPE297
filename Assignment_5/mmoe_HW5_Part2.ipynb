# %% [markdown]
# #CMPE 297 - Assignment 5 - Part 2
# ## Abhishek Bais
#
# **Acknowledgements**
# [Colab 1](https://github.com/drawbridge/keras-mmoe/blob/master/mmoe.py)
# [Colab 2](https://github.com/drawbridge/keras-mmoe/blob/master/synthetic_demo.py)
# **Dataset:** synthetic

# %% [markdown]
# #1.0 Build the model

# %%
"""
Multi-gate Mixture-of-Experts model implementation.
Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Alvin Deng
"""

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import activations, initializers, regularizers, constraints
from tensorflow.keras.layers import Layer, InputSpec


class MMoE(Layer):
    """
    Multi-gate Mixture-of-Experts model.
    """

    def __init__(self,
                 units,
                 num_experts,
                 num_tasks,
                 use_expert_bias=True,
                 use_gate_bias=True,
                 expert_activation='relu',
                 gate_activation='softmax',
                 expert_bias_initializer='zeros',
                 gate_bias_initializer='zeros',
                 expert_bias_regularizer=None,
                 gate_bias_regularizer=None,
                 expert_bias_constraint=None,
                 gate_bias_constraint=None,
                 expert_kernel_initializer='VarianceScaling',
                 gate_kernel_initializer='VarianceScaling',
                 expert_kernel_regularizer=None,
                 gate_kernel_regularizer=None,
                 expert_kernel_constraint=None,
                 gate_kernel_constraint=None,
                 activity_regularizer=None,
                 **kwargs):
        """
         Method for instantiating MMoE layer.
        :param units: Number of hidden units
        :param num_experts: Number of experts
        :param num_tasks: Number of tasks
        :param use_expert_bias: Boolean to indicate the usage of bias in the expert weights
        :param use_gate_bias: Boolean to indicate the usage of bias in the gate weights
        :param expert_activation: Activation function of the expert weights
        :param gate_activation: Activation function of the gate weights
        :param expert_bias_initializer: Initializer for the expert bias
        :param gate_bias_initializer: Initializer for the gate bias
        :param expert_bias_regularizer: Regularizer for the expert bias
        :param gate_bias_regularizer: Regularizer for the gate bias
        :param expert_bias_constraint: Constraint for the expert bias
        :param gate_bias_constraint: Constraint for the gate bias
        :param expert_kernel_initializer: Initializer for the expert weights
        :param gate_kernel_initializer: Initializer for the gate weights
        :param expert_kernel_regularizer: Regularizer for the expert weights
        :param gate_kernel_regularizer: Regularizer for the gate weights
        :param expert_kernel_constraint: Constraint for the expert weights
        :param gate_kernel_constraint: Constraint for the gate weights
        :param activity_regularizer: Regularizer for the activity
        :param kwargs: Additional keyword arguments for the Layer class
        """
        # Hidden nodes parameter
        self.units = units
        self.num_experts = num_experts
        self.num_tasks = num_tasks

        # Weight parameter
        self.expert_kernels = None
        self.gate_kernels = None
        self.expert_kernel_initializer = initializers.get(expert_kernel_initializer)
        self.gate_kernel_initializer = initializers.get(gate_kernel_initializer)
        self.expert_kernel_regularizer = regularizers.get(expert_kernel_regularizer)
        self.gate_kernel_regularizer = regularizers.get(gate_kernel_regularizer)
        self.expert_kernel_constraint = constraints.get(expert_kernel_constraint)
        self.gate_kernel_constraint = constraints.get(gate_kernel_constraint)

        # Activation parameter
        self.expert_activation = activations.get(expert_activation)
        self.gate_activation = activations.get(gate_activation)

        # Bias parameter
        self.expert_bias = None
        self.gate_bias = None
        self.use_expert_bias = use_expert_bias
        self.use_gate_bias = use_gate_bias
        self.expert_bias_initializer = initializers.get(expert_bias_initializer)
        self.gate_bias_initializer = initializers.get(gate_bias_initializer)
        self.expert_bias_regularizer = regularizers.get(expert_bias_regularizer)
        self.gate_bias_regularizer = regularizers.get(gate_bias_regularizer)
        self.expert_bias_constraint = constraints.get(expert_bias_constraint)
        self.gate_bias_constraint = constraints.get(gate_bias_constraint)

        # Activity parameter
        self.activity_regularizer = regularizers.get(activity_regularizer)

        # Keras parameter
        self.input_spec = InputSpec(min_ndim=2)
        self.supports_masking = True

        super(MMoE, self).__init__(**kwargs)

    def build(self, input_shape):
        """
        Method for creating the layer weights.
        :param input_shape: Keras tensor (future input to layer)
                            or list/tuple of Keras tensors to reference
                            for weight shape computations
        """
        assert input_shape is not None and len(input_shape) >= 2

        input_dimension = input_shape[-1]

        # Initialize expert weights (number of input features * number of units per expert * number of experts)
        self.expert_kernels = self.add_weight(
            name='expert_kernel',
            shape=(input_dimension, self.units, self.num_experts),
            initializer=self.expert_kernel_initializer,
            regularizer=self.expert_kernel_regularizer,
            constraint=self.expert_kernel_constraint,
        )

        # Initialize expert bias (number of units per expert * number of experts)
        if self.use_expert_bias:
            self.expert_bias = self.add_weight(
                name='expert_bias',
                shape=(self.units, self.num_experts),
                initializer=self.expert_bias_initializer,
                regularizer=self.expert_bias_regularizer,
                constraint=self.expert_bias_constraint,
            )

        # Initialize gate weights (number of input features * number of experts * number of tasks)
        self.gate_kernels = [self.add_weight(
            name='gate_kernel_task_{}'.format(i),
            shape=(input_dimension, self.num_experts),
            initializer=self.gate_kernel_initializer,
            regularizer=self.gate_kernel_regularizer,
            constraint=self.gate_kernel_constraint
        ) for i in range(self.num_tasks)]

        # Initialize gate bias (number of experts * number of tasks)
        if self.use_gate_bias:
            self.gate_bias = [self.add_weight(
                name='gate_bias_task_{}'.format(i),
                shape=(self.num_experts,),
                initializer=self.gate_bias_initializer,
                regularizer=self.gate_bias_regularizer,
                constraint=self.gate_bias_constraint
            ) for i in range(self.num_tasks)]

        self.input_spec = InputSpec(min_ndim=2, axes={-1: input_dimension})

        super(MMoE, self).build(input_shape)

    def call(self, inputs, **kwargs):
        """
        Method for the forward function of the layer.
        :param inputs: Input tensor
        :param kwargs: Additional keyword arguments for the base method
        :return: A tensor
        """
        gate_outputs = []
        final_outputs = []

        # f_{i}(x) = activation(W_{i} * x + b), where activation is ReLU according to the paper
        expert_outputs = tf.tensordot(a=inputs, b=self.expert_kernels, axes=1)
        # Add the bias term to the expert weights if necessary
        if self.use_expert_bias:
            expert_outputs = K.bias_add(x=expert_outputs, bias=self.expert_bias)
        expert_outputs = self.expert_activation(expert_outputs)

        # g^{k}(x) = activation(W_{gk} * x + b), where activation is softmax according to the paper
        for index, gate_kernel in enumerate(self.gate_kernels):
            gate_output = K.dot(x=inputs, y=gate_kernel)
            # Add the bias term to the gate weights if necessary
            if self.use_gate_bias:
                gate_output = K.bias_add(x=gate_output, bias=self.gate_bias[index])
            gate_output = self.gate_activation(gate_output)
            gate_outputs.append(gate_output)

        # f^{k}(x) = sum_{i=1}^{n}(g^{k}(x)_{i} * f_{i}(x))
        for gate_output in gate_outputs:
            expanded_gate_output = K.expand_dims(gate_output, axis=1)
            weighted_expert_output = expert_outputs * K.repeat_elements(expanded_gate_output, self.units, axis=1)
            final_outputs.append(K.sum(weighted_expert_output, axis=2))

        return final_outputs

    def compute_output_shape(self, input_shape):
        """
        Method for computing the output shape of the MMoE layer.
        :param input_shape: Shape tuple (tuple of integers)
        :return: List of input shape tuple where the size of the list is equal to the number of tasks
        """
        assert input_shape is not None and len(input_shape) >= 2

        output_shape = list(input_shape)
        output_shape[-1] = self.units
        output_shape = tuple(output_shape)

        return [output_shape for _ in range(self.num_tasks)]

    def get_config(self):
        """
        Method for returning the configuration of the MMoE layer.
        :return: Config dictionary
        """
        config = {
            'units': self.units,
            'num_experts': self.num_experts,
            'num_tasks': self.num_tasks,
            'use_expert_bias': self.use_expert_bias,
            'use_gate_bias': self.use_gate_bias,
            'expert_activation': activations.serialize(self.expert_activation),
            'gate_activation': activations.serialize(self.gate_activation),
            'expert_bias_initializer': initializers.serialize(self.expert_bias_initializer),
            'gate_bias_initializer': initializers.serialize(self.gate_bias_initializer),
            'expert_bias_regularizer': regularizers.serialize(self.expert_bias_regularizer),
            'gate_bias_regularizer': regularizers.serialize(self.gate_bias_regularizer),
            'expert_bias_constraint': constraints.serialize(self.expert_bias_constraint),
            'gate_bias_constraint': constraints.serialize(self.gate_bias_constraint),
            'expert_kernel_initializer': initializers.serialize(self.expert_kernel_initializer),
            'gate_kernel_initializer': initializers.serialize(self.gate_kernel_initializer),
            'expert_kernel_regularizer': regularizers.serialize(self.expert_kernel_regularizer),
            'gate_kernel_regularizer': regularizers.serialize(self.gate_kernel_regularizer),
            'expert_kernel_constraint': constraints.serialize(self.expert_kernel_constraint),
            'gate_kernel_constraint': constraints.serialize(self.gate_kernel_constraint),
            'activity_regularizer': regularizers.serialize(self.activity_regularizer)
        }
        base_config = super(MMoE, self).get_config()

        return dict(list(base_config.items()) + list(config.items()))

# %% [markdown]
# # 2.0 Build a synthetic dataset

# %%
"""
Multi-gate Mixture-of-Experts demo with census income data.
Copyright (c) 2018 Drawbridge, Inc
Licensed under the MIT License (see LICENSE for details)
Written by Peizhou Liao
"""

import random

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras import metrics
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import VarianceScaling
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

SEED = 1

# Fix numpy seed for reproducibility
np.random.seed(SEED)

# Fix random seed for reproducibility
random.seed(SEED)

# Fix TensorFlow graph-level seed for reproducibility
tf.random.set_seed(SEED)

def data_preparation():
    # Synthetic data hyper parameters
    num_dimension = 100
    num_row = 12000
    c = 0.3
    rho = 0.8
    m = 5

    # Initialize vectors u1, u2, w1, and w2 according to the paper
    mu1 = np.random.normal(size=num_dimension)
    mu1 = (mu1 - np.mean(mu1)) / (np.std(mu1) * np.sqrt(num_dimension))
    mu2 = np.random.normal(size=num_dimension)
    mu2 -= mu2.dot(mu1) * mu1
    mu2 /= np.linalg.norm(mu2)
    w1 = c * mu1
    w2 = c * (rho * mu1 + np.sqrt(1. - rho ** 2) * mu2)

    # Feature and label generation
    alpha = np.random.normal(size=m)
    beta = np.random.normal(size=m)
    y0 = []
    y1 = []
    X = []

    for i in range(num_row):
        x = np.random.normal(size=num_dimension)
        X.append(x)
        num1 = w1.dot(x)
        num2 = w2.dot(x)
        comp1, comp2 = 0.0, 0.0

        for j in range(m):
            comp1 += np.sin(alpha[j] * num1 + beta[j])
            comp2 += np.sin(alpha[j] * num2 + beta[j])

        y0.append(num1 + comp1 + np.random.normal(scale=0.1, size=1))
        y1.append(num2 + comp2 + np.random.normal(scale=0.1, size=1))

    y0 = np.array(y0)
    y1 = np.array(y1)
    X = np.array(X)
    data = pd.DataFrame(
        data=X,
        index=range(X.shape[0]),
        columns=['x{}'.format(it) for it in range(X.shape[1])]
    )

    train_data = data.iloc[0:10000]
    train_label = [y0[0:10000], y1[0:10000]]
    validation_data = data.iloc[10000:]
    validation_label = [y0[10000:], y1[10000:]]

    return train_data, train_label, validation_data, validation_label

# %% [markdown]
# #3.0 Train the model

# %%
    # Load the data
    train_data, train_label, validation_data, validation_label = data_preparation()
    num_features = train_data.shape[1]

    print('Training data shape = {}'.format(train_data.shape))
    print('Validation data shape = {}'.format(validation_data.shape))
    print('Test data shape = {}'.format(test_data.shape))

    # Set up the input layer
    input_layer = Input(shape=(num_features,))

    # Set up MMoE layer
    mmoe_layers = MMoE(
        units=16,
        num_experts=8,
        num_tasks=2
    )(input_layer)

    output_layers = []
    output_info = ['y0', 'y1']

    # Build tower layer from MMoE layer
    for index, task_layer in enumerate(mmoe_layers):
        tower_layer = Dense(
            units=8,
            activation='relu',
            kernel_initializer=VarianceScaling())(task_layer)
        output_layer = Dense(
            units=1,
            name=output_info[index],
            activation='linear',
            kernel_initializer=VarianceScaling())(tower_layer)
        output_layers.append(output_layer)

    # Compile model
    model = Model(inputs=[input_layer], outputs=output_layers)
    learning_rates = [1e-4, 1e-3, 1e-2]
    adam_optimizer = Adam(lr=learning_rates[0])
    model.compile(
        loss={'y0': 'mean_squared_error', 'y1': 'mean_squared_error'},
        optimizer=adam_optimizer,
        metrics=[metrics.mae]
    )

    # Print out model architecture summary
    model.summary()

    # Train the model
    history = model.fit(x=train_data, y=train_label, validation_data=(validation_data, validation_label), epochs=100)
# Out:
# Training data shape = (10000, 100)
# Validation data shape = (2000, 100)
# Test data shape = (1000, 100)
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            [(None, 100)]        0
# __________________________________________________________________________________________________
# m_mo_e_5 (MMoE)                 [(None, 16), (None,  14544       input_6[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 8)            136         m_mo_e_5[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 8)            136         m_mo_e_5[0][1]
# __________________________________________________________________________________________________
# y0 (Dense)                      (None, 1)            9           dense_10[0][0]
# __________________________________________________________________________________________________
# y1 (Dense)                      (None, 1)            9           dense_11[0][0]
# ==================================================================================================
# Total params: 14,834
# Trainable params: 14,834
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/100
# 313/313 [==============================] - 2s 4ms/step - loss: 1.5915 - y0_loss: 0.8038 - y1_loss: 0.7877 - y0_mean_absolute_error: 0.8607 - y1_mean_absolute_error: 0.8527 - val_loss: 0.9602 - val_y0_loss: 0.4797 - val_y1_loss: 0.4805 - val_y0_mean_absolute_error: 0.6558 - val_y1_mean_absolute_error: 0.6577
# Epoch 2/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4863 - y0_loss: 0.2455 - y1_loss: 0.2408 - y0_mean_absolute_error: 0.4353 - y1_mean_absolute_error: 0.4279 - val_loss: 0.1895 - val_y0_loss: 0.0982 - val_y1_loss: 0.0913 - val_y0_mean_absolute_error: 0.2625 - val_y1_mean_absolute_error: 0.2511
# Epoch 3/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1262 - y0_loss: 0.0637 - y1_loss: 0.0626 - y0_mean_absolute_error: 0.2039 - y1_mean_absolute_error: 0.2010 - val_loss: 0.0985 - val_y0_loss: 0.0486 - val_y1_loss: 0.0500 - val_y0_mean_absolute_error: 0.1762 - val_y1_mean_absolute_error: 0.1762
# Epoch 4/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0835 - y0_loss: 0.0414 - y1_loss: 0.0421 - y0_mean_absolute_error: 0.1610 - y1_mean_absolute_error: 0.1617 - val_loss: 0.0776 - val_y0_loss: 0.0379 - val_y1_loss: 0.0397 - val_y0_mean_absolute_error: 0.1546 - val_y1_mean_absolute_error: 0.1557
# Epoch 5/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0656 - y0_loss: 0.0326 - y1_loss: 0.0330 - y0_mean_absolute_error: 0.1427 - y1_mean_absolute_error: 0.1433 - val_loss: 0.0651 - val_y0_loss: 0.0318 - val_y1_loss: 0.0334 - val_y0_mean_absolute_error: 0.1414 - val_y1_mean_absolute_error: 0.1419
# Epoch 6/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0540 - y0_loss: 0.0268 - y1_loss: 0.0272 - y0_mean_absolute_error: 0.1298 - y1_mean_absolute_error: 0.1303 - val_loss: 0.0567 - val_y0_loss: 0.0277 - val_y1_loss: 0.0291 - val_y0_mean_absolute_error: 0.1319 - val_y1_mean_absolute_error: 0.1322
# Epoch 7/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0459 - y0_loss: 0.0228 - y1_loss: 0.0231 - y0_mean_absolute_error: 0.1199 - y1_mean_absolute_error: 0.1205 - val_loss: 0.0507 - val_y0_loss: 0.0247 - val_y1_loss: 0.0260 - val_y0_mean_absolute_error: 0.1246 - val_y1_mean_absolute_error: 0.1245
# Epoch 8/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0402 - y0_loss: 0.0200 - y1_loss: 0.0202 - y0_mean_absolute_error: 0.1123 - y1_mean_absolute_error: 0.1128 - val_loss: 0.0463 - val_y0_loss: 0.0226 - val_y1_loss: 0.0237 - val_y0_mean_absolute_error: 0.1193 - val_y1_mean_absolute_error: 0.1194
# Epoch 9/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0360 - y0_loss: 0.0179 - y1_loss: 0.0181 - y0_mean_absolute_error: 0.1063 - y1_mean_absolute_error: 0.1070 - val_loss: 0.0432 - val_y0_loss: 0.0211 - val_y1_loss: 0.0221 - val_y0_mean_absolute_error: 0.1153 - val_y1_mean_absolute_error: 0.1153
# Epoch 10/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0329 - y0_loss: 0.0163 - y1_loss: 0.0166 - y0_mean_absolute_error: 0.1015 - y1_mean_absolute_error: 0.1022 - val_loss: 0.0407 - val_y0_loss: 0.0199 - val_y1_loss: 0.0208 - val_y0_mean_absolute_error: 0.1118 - val_y1_mean_absolute_error: 0.1118
# Epoch 11/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0305 - y0_loss: 0.0151 - y1_loss: 0.0154 - y0_mean_absolute_error: 0.0978 - y1_mean_absolute_error: 0.0983 - val_loss: 0.0391 - val_y0_loss: 0.0192 - val_y1_loss: 0.0199 - val_y0_mean_absolute_error: 0.1097 - val_y1_mean_absolute_error: 0.1092
# Epoch 12/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0286 - y0_loss: 0.0142 - y1_loss: 0.0144 - y0_mean_absolute_error: 0.0946 - y1_mean_absolute_error: 0.0951 - val_loss: 0.0377 - val_y0_loss: 0.0185 - val_y1_loss: 0.0192 - val_y0_mean_absolute_error: 0.1076 - val_y1_mean_absolute_error: 0.1073
# Epoch 13/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0270 - y0_loss: 0.0134 - y1_loss: 0.0136 - y0_mean_absolute_error: 0.0919 - y1_mean_absolute_error: 0.0924 - val_loss: 0.0366 - val_y0_loss: 0.0180 - val_y1_loss: 0.0186 - val_y0_mean_absolute_error: 0.1062 - val_y1_mean_absolute_error: 0.1056
# Epoch 14/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0256 - y0_loss: 0.0127 - y1_loss: 0.0129 - y0_mean_absolute_error: 0.0894 - y1_mean_absolute_error: 0.0899 - val_loss: 0.0356 - val_y0_loss: 0.0175 - val_y1_loss: 0.0181 - val_y0_mean_absolute_error: 0.1048 - val_y1_mean_absolute_error: 0.1044
# Epoch 15/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0244 - y0_loss: 0.0121 - y1_loss: 0.0123 - y0_mean_absolute_error: 0.0873 - y1_mean_absolute_error: 0.0878 - val_loss: 0.0347 - val_y0_loss: 0.0170 - val_y1_loss: 0.0176 - val_y0_mean_absolute_error: 0.1033 - val_y1_mean_absolute_error: 0.1030
# Epoch 16/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0233 - y0_loss: 0.0116 - y1_loss: 0.0118 - y0_mean_absolute_error: 0.0853 - y1_mean_absolute_error: 0.0858 - val_loss: 0.0342 - val_y0_loss: 0.0168 - val_y1_loss: 0.0174 - val_y0_mean_absolute_error: 0.1027 - val_y1_mean_absolute_error: 0.1023
# Epoch 17/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0224 - y0_loss: 0.0111 - y1_loss: 0.0112 - y0_mean_absolute_error: 0.0837 - y1_mean_absolute_error: 0.0839 - val_loss: 0.0335 - val_y0_loss: 0.0165 - val_y1_loss: 0.0170 - val_y0_mean_absolute_error: 0.1017 - val_y1_mean_absolute_error: 0.1015
# Epoch 18/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0215 - y0_loss: 0.0107 - y1_loss: 0.0108 - y0_mean_absolute_error: 0.0819 - y1_mean_absolute_error: 0.0823 - val_loss: 0.0332 - val_y0_loss: 0.0163 - val_y1_loss: 0.0168 - val_y0_mean_absolute_error: 0.1011 - val_y1_mean_absolute_error: 0.1009
# Epoch 19/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0207 - y0_loss: 0.0103 - y1_loss: 0.0104 - y0_mean_absolute_error: 0.0804 - y1_mean_absolute_error: 0.0807 - val_loss: 0.0328 - val_y0_loss: 0.0162 - val_y1_loss: 0.0166 - val_y0_mean_absolute_error: 0.1004 - val_y1_mean_absolute_error: 0.1005
# Epoch 20/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0199 - y0_loss: 0.0099 - y1_loss: 0.0100 - y0_mean_absolute_error: 0.0789 - y1_mean_absolute_error: 0.0791 - val_loss: 0.0328 - val_y0_loss: 0.0161 - val_y1_loss: 0.0166 - val_y0_mean_absolute_error: 0.1002 - val_y1_mean_absolute_error: 0.1004
# Epoch 21/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0192 - y0_loss: 0.0096 - y1_loss: 0.0096 - y0_mean_absolute_error: 0.0776 - y1_mean_absolute_error: 0.0778 - val_loss: 0.0324 - val_y0_loss: 0.0160 - val_y1_loss: 0.0164 - val_y0_mean_absolute_error: 0.0996 - val_y1_mean_absolute_error: 0.0996
# Epoch 22/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0186 - y0_loss: 0.0093 - y1_loss: 0.0093 - y0_mean_absolute_error: 0.0763 - y1_mean_absolute_error: 0.0764 - val_loss: 0.0321 - val_y0_loss: 0.0159 - val_y1_loss: 0.0162 - val_y0_mean_absolute_error: 0.0994 - val_y1_mean_absolute_error: 0.0994
# Epoch 23/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0179 - y0_loss: 0.0090 - y1_loss: 0.0090 - y0_mean_absolute_error: 0.0750 - y1_mean_absolute_error: 0.0752 - val_loss: 0.0321 - val_y0_loss: 0.0159 - val_y1_loss: 0.0162 - val_y0_mean_absolute_error: 0.0992 - val_y1_mean_absolute_error: 0.0995
# Epoch 24/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0174 - y0_loss: 0.0087 - y1_loss: 0.0087 - y0_mean_absolute_error: 0.0740 - y1_mean_absolute_error: 0.0738 - val_loss: 0.0320 - val_y0_loss: 0.0158 - val_y1_loss: 0.0162 - val_y0_mean_absolute_error: 0.0991 - val_y1_mean_absolute_error: 0.0993
# Epoch 25/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0168 - y0_loss: 0.0084 - y1_loss: 0.0084 - y0_mean_absolute_error: 0.0728 - y1_mean_absolute_error: 0.0727 - val_loss: 0.0318 - val_y0_loss: 0.0157 - val_y1_loss: 0.0160 - val_y0_mean_absolute_error: 0.0991 - val_y1_mean_absolute_error: 0.0990
# Epoch 26/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0164 - y0_loss: 0.0082 - y1_loss: 0.0082 - y0_mean_absolute_error: 0.0718 - y1_mean_absolute_error: 0.0716 - val_loss: 0.0319 - val_y0_loss: 0.0159 - val_y1_loss: 0.0160 - val_y0_mean_absolute_error: 0.0993 - val_y1_mean_absolute_error: 0.0991
# Epoch 27/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0159 - y0_loss: 0.0080 - y1_loss: 0.0079 - y0_mean_absolute_error: 0.0708 - y1_mean_absolute_error: 0.0705 - val_loss: 0.0318 - val_y0_loss: 0.0159 - val_y1_loss: 0.0160 - val_y0_mean_absolute_error: 0.0995 - val_y1_mean_absolute_error: 0.0990
# Epoch 28/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0154 - y0_loss: 0.0078 - y1_loss: 0.0077 - y0_mean_absolute_error: 0.0699 - y1_mean_absolute_error: 0.0695 - val_loss: 0.0319 - val_y0_loss: 0.0158 - val_y1_loss: 0.0160 - val_y0_mean_absolute_error: 0.0994 - val_y1_mean_absolute_error: 0.0992
# Epoch 29/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0150 - y0_loss: 0.0076 - y1_loss: 0.0075 - y0_mean_absolute_error: 0.0689 - y1_mean_absolute_error: 0.0687 - val_loss: 0.0319 - val_y0_loss: 0.0158 - val_y1_loss: 0.0161 - val_y0_mean_absolute_error: 0.0995 - val_y1_mean_absolute_error: 0.0992
# Epoch 30/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0146 - y0_loss: 0.0074 - y1_loss: 0.0073 - y0_mean_absolute_error: 0.0679 - y1_mean_absolute_error: 0.0678 - val_loss: 0.0322 - val_y0_loss: 0.0159 - val_y1_loss: 0.0163 - val_y0_mean_absolute_error: 0.0996 - val_y1_mean_absolute_error: 0.0998
# Epoch 31/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0143 - y0_loss: 0.0072 - y1_loss: 0.0071 - y0_mean_absolute_error: 0.0671 - y1_mean_absolute_error: 0.0669 - val_loss: 0.0322 - val_y0_loss: 0.0159 - val_y1_loss: 0.0163 - val_y0_mean_absolute_error: 0.0996 - val_y1_mean_absolute_error: 0.0998
# Epoch 32/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0139 - y0_loss: 0.0070 - y1_loss: 0.0069 - y0_mean_absolute_error: 0.0662 - y1_mean_absolute_error: 0.0661 - val_loss: 0.0324 - val_y0_loss: 0.0160 - val_y1_loss: 0.0164 - val_y0_mean_absolute_error: 0.0998 - val_y1_mean_absolute_error: 0.1003
# Epoch 33/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0136 - y0_loss: 0.0069 - y1_loss: 0.0067 - y0_mean_absolute_error: 0.0656 - y1_mean_absolute_error: 0.0652 - val_loss: 0.0322 - val_y0_loss: 0.0159 - val_y1_loss: 0.0164 - val_y0_mean_absolute_error: 0.0995 - val_y1_mean_absolute_error: 0.1002
# Epoch 34/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0133 - y0_loss: 0.0067 - y1_loss: 0.0066 - y0_mean_absolute_error: 0.0650 - y1_mean_absolute_error: 0.0644 - val_loss: 0.0324 - val_y0_loss: 0.0159 - val_y1_loss: 0.0164 - val_y0_mean_absolute_error: 0.1000 - val_y1_mean_absolute_error: 0.1003
# Epoch 35/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0130 - y0_loss: 0.0066 - y1_loss: 0.0064 - y0_mean_absolute_error: 0.0643 - y1_mean_absolute_error: 0.0637 - val_loss: 0.0326 - val_y0_loss: 0.0161 - val_y1_loss: 0.0165 - val_y0_mean_absolute_error: 0.1003 - val_y1_mean_absolute_error: 0.1007
# Epoch 36/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0127 - y0_loss: 0.0065 - y1_loss: 0.0063 - y0_mean_absolute_error: 0.0636 - y1_mean_absolute_error: 0.0629 - val_loss: 0.0327 - val_y0_loss: 0.0162 - val_y1_loss: 0.0166 - val_y0_mean_absolute_error: 0.1009 - val_y1_mean_absolute_error: 0.1009
# Epoch 37/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0125 - y0_loss: 0.0063 - y1_loss: 0.0062 - y0_mean_absolute_error: 0.0629 - y1_mean_absolute_error: 0.0623 - val_loss: 0.0329 - val_y0_loss: 0.0162 - val_y1_loss: 0.0167 - val_y0_mean_absolute_error: 0.1009 - val_y1_mean_absolute_error: 0.1013
# Epoch 38/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0123 - y0_loss: 0.0062 - y1_loss: 0.0060 - y0_mean_absolute_error: 0.0624 - y1_mean_absolute_error: 0.0618 - val_loss: 0.0331 - val_y0_loss: 0.0163 - val_y1_loss: 0.0168 - val_y0_mean_absolute_error: 0.1012 - val_y1_mean_absolute_error: 0.1013
# Epoch 39/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0120 - y0_loss: 0.0061 - y1_loss: 0.0059 - y0_mean_absolute_error: 0.0617 - y1_mean_absolute_error: 0.0611 - val_loss: 0.0331 - val_y0_loss: 0.0163 - val_y1_loss: 0.0168 - val_y0_mean_absolute_error: 0.1015 - val_y1_mean_absolute_error: 0.1014
# Epoch 40/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0118 - y0_loss: 0.0060 - y1_loss: 0.0058 - y0_mean_absolute_error: 0.0612 - y1_mean_absolute_error: 0.0604 - val_loss: 0.0333 - val_y0_loss: 0.0164 - val_y1_loss: 0.0169 - val_y0_mean_absolute_error: 0.1018 - val_y1_mean_absolute_error: 0.1016
# Epoch 41/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0116 - y0_loss: 0.0059 - y1_loss: 0.0057 - y0_mean_absolute_error: 0.0608 - y1_mean_absolute_error: 0.0599 - val_loss: 0.0336 - val_y0_loss: 0.0166 - val_y1_loss: 0.0171 - val_y0_mean_absolute_error: 0.1024 - val_y1_mean_absolute_error: 0.1023
# Epoch 42/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0114 - y0_loss: 0.0058 - y1_loss: 0.0056 - y0_mean_absolute_error: 0.0602 - y1_mean_absolute_error: 0.0593 - val_loss: 0.0337 - val_y0_loss: 0.0166 - val_y1_loss: 0.0171 - val_y0_mean_absolute_error: 0.1025 - val_y1_mean_absolute_error: 0.1024
# Epoch 43/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0112 - y0_loss: 0.0057 - y1_loss: 0.0055 - y0_mean_absolute_error: 0.0596 - y1_mean_absolute_error: 0.0588 - val_loss: 0.0338 - val_y0_loss: 0.0167 - val_y1_loss: 0.0172 - val_y0_mean_absolute_error: 0.1026 - val_y1_mean_absolute_error: 0.1024
# Epoch 44/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0110 - y0_loss: 0.0056 - y1_loss: 0.0054 - y0_mean_absolute_error: 0.0593 - y1_mean_absolute_error: 0.0583 - val_loss: 0.0341 - val_y0_loss: 0.0169 - val_y1_loss: 0.0172 - val_y0_mean_absolute_error: 0.1032 - val_y1_mean_absolute_error: 0.1028
# Epoch 45/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0108 - y0_loss: 0.0055 - y1_loss: 0.0053 - y0_mean_absolute_error: 0.0589 - y1_mean_absolute_error: 0.0577 - val_loss: 0.0340 - val_y0_loss: 0.0167 - val_y1_loss: 0.0173 - val_y0_mean_absolute_error: 0.1029 - val_y1_mean_absolute_error: 0.1029
# Epoch 46/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0107 - y0_loss: 0.0055 - y1_loss: 0.0052 - y0_mean_absolute_error: 0.0585 - y1_mean_absolute_error: 0.0573 - val_loss: 0.0343 - val_y0_loss: 0.0168 - val_y1_loss: 0.0174 - val_y0_mean_absolute_error: 0.1035 - val_y1_mean_absolute_error: 0.1032
# Epoch 47/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0105 - y0_loss: 0.0054 - y1_loss: 0.0051 - y0_mean_absolute_error: 0.0579 - y1_mean_absolute_error: 0.0568 - val_loss: 0.0345 - val_y0_loss: 0.0169 - val_y1_loss: 0.0176 - val_y0_mean_absolute_error: 0.1036 - val_y1_mean_absolute_error: 0.1039
# Epoch 48/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0103 - y0_loss: 0.0053 - y1_loss: 0.0050 - y0_mean_absolute_error: 0.0574 - y1_mean_absolute_error: 0.0563 - val_loss: 0.0347 - val_y0_loss: 0.0170 - val_y1_loss: 0.0176 - val_y0_mean_absolute_error: 0.1040 - val_y1_mean_absolute_error: 0.1039
# Epoch 49/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0102 - y0_loss: 0.0052 - y1_loss: 0.0050 - y0_mean_absolute_error: 0.0570 - y1_mean_absolute_error: 0.0559 - val_loss: 0.0349 - val_y0_loss: 0.0173 - val_y1_loss: 0.0177 - val_y0_mean_absolute_error: 0.1047 - val_y1_mean_absolute_error: 0.1040
# Epoch 50/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0100 - y0_loss: 0.0052 - y1_loss: 0.0049 - y0_mean_absolute_error: 0.0567 - y1_mean_absolute_error: 0.0553 - val_loss: 0.0349 - val_y0_loss: 0.0172 - val_y1_loss: 0.0177 - val_y0_mean_absolute_error: 0.1045 - val_y1_mean_absolute_error: 0.1044
# Epoch 51/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0099 - y0_loss: 0.0051 - y1_loss: 0.0048 - y0_mean_absolute_error: 0.0562 - y1_mean_absolute_error: 0.0549 - val_loss: 0.0350 - val_y0_loss: 0.0172 - val_y1_loss: 0.0178 - val_y0_mean_absolute_error: 0.1046 - val_y1_mean_absolute_error: 0.1045
# Epoch 52/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0098 - y0_loss: 0.0050 - y1_loss: 0.0047 - y0_mean_absolute_error: 0.0560 - y1_mean_absolute_error: 0.0546 - val_loss: 0.0352 - val_y0_loss: 0.0174 - val_y1_loss: 0.0178 - val_y0_mean_absolute_error: 0.1054 - val_y1_mean_absolute_error: 0.1043
# Epoch 53/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0096 - y0_loss: 0.0050 - y1_loss: 0.0047 - y0_mean_absolute_error: 0.0557 - y1_mean_absolute_error: 0.0541 - val_loss: 0.0355 - val_y0_loss: 0.0174 - val_y1_loss: 0.0180 - val_y0_mean_absolute_error: 0.1053 - val_y1_mean_absolute_error: 0.1050
# Epoch 54/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0095 - y0_loss: 0.0049 - y1_loss: 0.0046 - y0_mean_absolute_error: 0.0552 - y1_mean_absolute_error: 0.0538 - val_loss: 0.0357 - val_y0_loss: 0.0176 - val_y1_loss: 0.0181 - val_y0_mean_absolute_error: 0.1058 - val_y1_mean_absolute_error: 0.1053
# Epoch 55/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0094 - y0_loss: 0.0049 - y1_loss: 0.0045 - y0_mean_absolute_error: 0.0550 - y1_mean_absolute_error: 0.0533 - val_loss: 0.0357 - val_y0_loss: 0.0176 - val_y1_loss: 0.0181 - val_y0_mean_absolute_error: 0.1058 - val_y1_mean_absolute_error: 0.1053
# Epoch 56/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0093 - y0_loss: 0.0048 - y1_loss: 0.0045 - y0_mean_absolute_error: 0.0545 - y1_mean_absolute_error: 0.0529 - val_loss: 0.0358 - val_y0_loss: 0.0176 - val_y1_loss: 0.0182 - val_y0_mean_absolute_error: 0.1060 - val_y1_mean_absolute_error: 0.1055
# Epoch 57/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0091 - y0_loss: 0.0047 - y1_loss: 0.0044 - y0_mean_absolute_error: 0.0543 - y1_mean_absolute_error: 0.0526 - val_loss: 0.0359 - val_y0_loss: 0.0177 - val_y1_loss: 0.0183 - val_y0_mean_absolute_error: 0.1066 - val_y1_mean_absolute_error: 0.1056
# Epoch 58/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0091 - y0_loss: 0.0047 - y1_loss: 0.0044 - y0_mean_absolute_error: 0.0539 - y1_mean_absolute_error: 0.0524 - val_loss: 0.0361 - val_y0_loss: 0.0177 - val_y1_loss: 0.0183 - val_y0_mean_absolute_error: 0.1067 - val_y1_mean_absolute_error: 0.1059
# Epoch 59/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0089 - y0_loss: 0.0046 - y1_loss: 0.0043 - y0_mean_absolute_error: 0.0536 - y1_mean_absolute_error: 0.0519 - val_loss: 0.0364 - val_y0_loss: 0.0179 - val_y1_loss: 0.0185 - val_y0_mean_absolute_error: 0.1071 - val_y1_mean_absolute_error: 0.1061
# Epoch 60/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0088 - y0_loss: 0.0046 - y1_loss: 0.0043 - y0_mean_absolute_error: 0.0532 - y1_mean_absolute_error: 0.0517 - val_loss: 0.0365 - val_y0_loss: 0.0179 - val_y1_loss: 0.0186 - val_y0_mean_absolute_error: 0.1074 - val_y1_mean_absolute_error: 0.1067
# Epoch 61/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0087 - y0_loss: 0.0045 - y1_loss: 0.0042 - y0_mean_absolute_error: 0.0529 - y1_mean_absolute_error: 0.0513 - val_loss: 0.0366 - val_y0_loss: 0.0180 - val_y1_loss: 0.0186 - val_y0_mean_absolute_error: 0.1075 - val_y1_mean_absolute_error: 0.1067
# Epoch 62/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0086 - y0_loss: 0.0045 - y1_loss: 0.0041 - y0_mean_absolute_error: 0.0527 - y1_mean_absolute_error: 0.0508 - val_loss: 0.0367 - val_y0_loss: 0.0181 - val_y1_loss: 0.0187 - val_y0_mean_absolute_error: 0.1077 - val_y1_mean_absolute_error: 0.1068
# Epoch 63/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0085 - y0_loss: 0.0044 - y1_loss: 0.0041 - y0_mean_absolute_error: 0.0523 - y1_mean_absolute_error: 0.0506 - val_loss: 0.0369 - val_y0_loss: 0.0181 - val_y1_loss: 0.0188 - val_y0_mean_absolute_error: 0.1079 - val_y1_mean_absolute_error: 0.1072
# Epoch 64/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0084 - y0_loss: 0.0044 - y1_loss: 0.0041 - y0_mean_absolute_error: 0.0521 - y1_mean_absolute_error: 0.0504 - val_loss: 0.0369 - val_y0_loss: 0.0182 - val_y1_loss: 0.0188 - val_y0_mean_absolute_error: 0.1079 - val_y1_mean_absolute_error: 0.1073
# Epoch 65/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0083 - y0_loss: 0.0043 - y1_loss: 0.0040 - y0_mean_absolute_error: 0.0518 - y1_mean_absolute_error: 0.0499 - val_loss: 0.0371 - val_y0_loss: 0.0182 - val_y1_loss: 0.0189 - val_y0_mean_absolute_error: 0.1083 - val_y1_mean_absolute_error: 0.1075
# Epoch 66/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0082 - y0_loss: 0.0043 - y1_loss: 0.0040 - y0_mean_absolute_error: 0.0514 - y1_mean_absolute_error: 0.0499 - val_loss: 0.0374 - val_y0_loss: 0.0184 - val_y1_loss: 0.0191 - val_y0_mean_absolute_error: 0.1087 - val_y1_mean_absolute_error: 0.1079
# Epoch 67/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0081 - y0_loss: 0.0042 - y1_loss: 0.0039 - y0_mean_absolute_error: 0.0513 - y1_mean_absolute_error: 0.0494 - val_loss: 0.0376 - val_y0_loss: 0.0185 - val_y1_loss: 0.0191 - val_y0_mean_absolute_error: 0.1090 - val_y1_mean_absolute_error: 0.1078
# Epoch 68/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0081 - y0_loss: 0.0042 - y1_loss: 0.0039 - y0_mean_absolute_error: 0.0509 - y1_mean_absolute_error: 0.0491 - val_loss: 0.0379 - val_y0_loss: 0.0188 - val_y1_loss: 0.0192 - val_y0_mean_absolute_error: 0.1096 - val_y1_mean_absolute_error: 0.1081
# Epoch 69/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0080 - y0_loss: 0.0041 - y1_loss: 0.0038 - y0_mean_absolute_error: 0.0506 - y1_mean_absolute_error: 0.0489 - val_loss: 0.0381 - val_y0_loss: 0.0188 - val_y1_loss: 0.0193 - val_y0_mean_absolute_error: 0.1099 - val_y1_mean_absolute_error: 0.1085
# Epoch 70/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0079 - y0_loss: 0.0041 - y1_loss: 0.0038 - y0_mean_absolute_error: 0.0504 - y1_mean_absolute_error: 0.0486 - val_loss: 0.0379 - val_y0_loss: 0.0187 - val_y1_loss: 0.0193 - val_y0_mean_absolute_error: 0.1098 - val_y1_mean_absolute_error: 0.1085
# Epoch 71/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0078 - y0_loss: 0.0041 - y1_loss: 0.0037 - y0_mean_absolute_error: 0.0501 - y1_mean_absolute_error: 0.0483 - val_loss: 0.0384 - val_y0_loss: 0.0189 - val_y1_loss: 0.0194 - val_y0_mean_absolute_error: 0.1104 - val_y1_mean_absolute_error: 0.1091
# Epoch 72/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0077 - y0_loss: 0.0040 - y1_loss: 0.0037 - y0_mean_absolute_error: 0.0500 - y1_mean_absolute_error: 0.0482 - val_loss: 0.0384 - val_y0_loss: 0.0191 - val_y1_loss: 0.0194 - val_y0_mean_absolute_error: 0.1107 - val_y1_mean_absolute_error: 0.1087
# Epoch 73/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0076 - y0_loss: 0.0040 - y1_loss: 0.0037 - y0_mean_absolute_error: 0.0496 - y1_mean_absolute_error: 0.0476 - val_loss: 0.0384 - val_y0_loss: 0.0190 - val_y1_loss: 0.0194 - val_y0_mean_absolute_error: 0.1104 - val_y1_mean_absolute_error: 0.1091
# Epoch 74/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0076 - y0_loss: 0.0039 - y1_loss: 0.0036 - y0_mean_absolute_error: 0.0493 - y1_mean_absolute_error: 0.0476 - val_loss: 0.0388 - val_y0_loss: 0.0191 - val_y1_loss: 0.0197 - val_y0_mean_absolute_error: 0.1110 - val_y1_mean_absolute_error: 0.1097
# Epoch 75/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0075 - y0_loss: 0.0039 - y1_loss: 0.0036 - y0_mean_absolute_error: 0.0492 - y1_mean_absolute_error: 0.0473 - val_loss: 0.0390 - val_y0_loss: 0.0193 - val_y1_loss: 0.0197 - val_y0_mean_absolute_error: 0.1113 - val_y1_mean_absolute_error: 0.1094
# Epoch 76/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0074 - y0_loss: 0.0039 - y1_loss: 0.0035 - y0_mean_absolute_error: 0.0488 - y1_mean_absolute_error: 0.0470 - val_loss: 0.0391 - val_y0_loss: 0.0192 - val_y1_loss: 0.0199 - val_y0_mean_absolute_error: 0.1112 - val_y1_mean_absolute_error: 0.1103
# Epoch 77/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0073 - y0_loss: 0.0038 - y1_loss: 0.0035 - y0_mean_absolute_error: 0.0486 - y1_mean_absolute_error: 0.0467 - val_loss: 0.0391 - val_y0_loss: 0.0193 - val_y1_loss: 0.0198 - val_y0_mean_absolute_error: 0.1117 - val_y1_mean_absolute_error: 0.1101
# Epoch 78/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0073 - y0_loss: 0.0038 - y1_loss: 0.0035 - y0_mean_absolute_error: 0.0484 - y1_mean_absolute_error: 0.0466 - val_loss: 0.0393 - val_y0_loss: 0.0193 - val_y1_loss: 0.0200 - val_y0_mean_absolute_error: 0.1116 - val_y1_mean_absolute_error: 0.1105
# Epoch 79/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0072 - y0_loss: 0.0038 - y1_loss: 0.0034 - y0_mean_absolute_error: 0.0482 - y1_mean_absolute_error: 0.0464 - val_loss: 0.0394 - val_y0_loss: 0.0194 - val_y1_loss: 0.0200 - val_y0_mean_absolute_error: 0.1116 - val_y1_mean_absolute_error: 0.1107
# Epoch 80/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0071 - y0_loss: 0.0037 - y1_loss: 0.0034 - y0_mean_absolute_error: 0.0480 - y1_mean_absolute_error: 0.0461 - val_loss: 0.0394 - val_y0_loss: 0.0193 - val_y1_loss: 0.0201 - val_y0_mean_absolute_error: 0.1118 - val_y1_mean_absolute_error: 0.1110
# Epoch 81/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0071 - y0_loss: 0.0037 - y1_loss: 0.0034 - y0_mean_absolute_error: 0.0479 - y1_mean_absolute_error: 0.0459 - val_loss: 0.0398 - val_y0_loss: 0.0195 - val_y1_loss: 0.0203 - val_y0_mean_absolute_error: 0.1122 - val_y1_mean_absolute_error: 0.1113
# Epoch 82/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0070 - y0_loss: 0.0037 - y1_loss: 0.0034 - y0_mean_absolute_error: 0.0476 - y1_mean_absolute_error: 0.0458 - val_loss: 0.0397 - val_y0_loss: 0.0195 - val_y1_loss: 0.0202 - val_y0_mean_absolute_error: 0.1123 - val_y1_mean_absolute_error: 0.1115
# Epoch 83/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0070 - y0_loss: 0.0036 - y1_loss: 0.0033 - y0_mean_absolute_error: 0.0473 - y1_mean_absolute_error: 0.0455 - val_loss: 0.0400 - val_y0_loss: 0.0197 - val_y1_loss: 0.0204 - val_y0_mean_absolute_error: 0.1125 - val_y1_mean_absolute_error: 0.1118
# Epoch 84/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0069 - y0_loss: 0.0036 - y1_loss: 0.0033 - y0_mean_absolute_error: 0.0472 - y1_mean_absolute_error: 0.0454 - val_loss: 0.0404 - val_y0_loss: 0.0199 - val_y1_loss: 0.0204 - val_y0_mean_absolute_error: 0.1133 - val_y1_mean_absolute_error: 0.1120
# Epoch 85/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0068 - y0_loss: 0.0036 - y1_loss: 0.0033 - y0_mean_absolute_error: 0.0470 - y1_mean_absolute_error: 0.0451 - val_loss: 0.0404 - val_y0_loss: 0.0198 - val_y1_loss: 0.0206 - val_y0_mean_absolute_error: 0.1129 - val_y1_mean_absolute_error: 0.1123
# Epoch 86/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0068 - y0_loss: 0.0035 - y1_loss: 0.0032 - y0_mean_absolute_error: 0.0468 - y1_mean_absolute_error: 0.0449 - val_loss: 0.0406 - val_y0_loss: 0.0200 - val_y1_loss: 0.0206 - val_y0_mean_absolute_error: 0.1136 - val_y1_mean_absolute_error: 0.1123
# Epoch 87/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0067 - y0_loss: 0.0035 - y1_loss: 0.0032 - y0_mean_absolute_error: 0.0465 - y1_mean_absolute_error: 0.0448 - val_loss: 0.0407 - val_y0_loss: 0.0200 - val_y1_loss: 0.0208 - val_y0_mean_absolute_error: 0.1135 - val_y1_mean_absolute_error: 0.1127
# Epoch 88/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0067 - y0_loss: 0.0035 - y1_loss: 0.0032 - y0_mean_absolute_error: 0.0463 - y1_mean_absolute_error: 0.0445 - val_loss: 0.0409 - val_y0_loss: 0.0201 - val_y1_loss: 0.0208 - val_y0_mean_absolute_error: 0.1137 - val_y1_mean_absolute_error: 0.1130
# Epoch 89/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0066 - y0_loss: 0.0035 - y1_loss: 0.0032 - y0_mean_absolute_error: 0.0463 - y1_mean_absolute_error: 0.0444 - val_loss: 0.0410 - val_y0_loss: 0.0201 - val_y1_loss: 0.0209 - val_y0_mean_absolute_error: 0.1138 - val_y1_mean_absolute_error: 0.1131
# Epoch 90/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0066 - y0_loss: 0.0034 - y1_loss: 0.0031 - y0_mean_absolute_error: 0.0460 - y1_mean_absolute_error: 0.0442 - val_loss: 0.0410 - val_y0_loss: 0.0201 - val_y1_loss: 0.0209 - val_y0_mean_absolute_error: 0.1138 - val_y1_mean_absolute_error: 0.1133
# Epoch 91/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0065 - y0_loss: 0.0034 - y1_loss: 0.0031 - y0_mean_absolute_error: 0.0457 - y1_mean_absolute_error: 0.0441 - val_loss: 0.0415 - val_y0_loss: 0.0205 - val_y1_loss: 0.0211 - val_y0_mean_absolute_error: 0.1147 - val_y1_mean_absolute_error: 0.1137
# Epoch 92/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0065 - y0_loss: 0.0034 - y1_loss: 0.0031 - y0_mean_absolute_error: 0.0457 - y1_mean_absolute_error: 0.0437 - val_loss: 0.0416 - val_y0_loss: 0.0205 - val_y1_loss: 0.0212 - val_y0_mean_absolute_error: 0.1147 - val_y1_mean_absolute_error: 0.1140
# Epoch 93/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0064 - y0_loss: 0.0034 - y1_loss: 0.0031 - y0_mean_absolute_error: 0.0454 - y1_mean_absolute_error: 0.0436 - val_loss: 0.0416 - val_y0_loss: 0.0204 - val_y1_loss: 0.0212 - val_y0_mean_absolute_error: 0.1146 - val_y1_mean_absolute_error: 0.1139
# Epoch 94/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0064 - y0_loss: 0.0033 - y1_loss: 0.0031 - y0_mean_absolute_error: 0.0452 - y1_mean_absolute_error: 0.0436 - val_loss: 0.0418 - val_y0_loss: 0.0205 - val_y1_loss: 0.0212 - val_y0_mean_absolute_error: 0.1149 - val_y1_mean_absolute_error: 0.1140
# Epoch 95/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0063 - y0_loss: 0.0033 - y1_loss: 0.0030 - y0_mean_absolute_error: 0.0452 - y1_mean_absolute_error: 0.0433 - val_loss: 0.0418 - val_y0_loss: 0.0206 - val_y1_loss: 0.0212 - val_y0_mean_absolute_error: 0.1151 - val_y1_mean_absolute_error: 0.1140
# Epoch 96/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0063 - y0_loss: 0.0033 - y1_loss: 0.0030 - y0_mean_absolute_error: 0.0450 - y1_mean_absolute_error: 0.0431 - val_loss: 0.0420 - val_y0_loss: 0.0206 - val_y1_loss: 0.0214 - val_y0_mean_absolute_error: 0.1151 - val_y1_mean_absolute_error: 0.1148
# Epoch 97/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0062 - y0_loss: 0.0033 - y1_loss: 0.0030 - y0_mean_absolute_error: 0.0447 - y1_mean_absolute_error: 0.0430 - val_loss: 0.0422 - val_y0_loss: 0.0207 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1154 - val_y1_mean_absolute_error: 0.1150
# Epoch 98/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0062 - y0_loss: 0.0032 - y1_loss: 0.0030 - y0_mean_absolute_error: 0.0447 - y1_mean_absolute_error: 0.0428 - val_loss: 0.0422 - val_y0_loss: 0.0208 - val_y1_loss: 0.0214 - val_y0_mean_absolute_error: 0.1157 - val_y1_mean_absolute_error: 0.1147
# Epoch 99/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0062 - y0_loss: 0.0032 - y1_loss: 0.0029 - y0_mean_absolute_error: 0.0446 - y1_mean_absolute_error: 0.0428 - val_loss: 0.0426 - val_y0_loss: 0.0209 - val_y1_loss: 0.0217 - val_y0_mean_absolute_error: 0.1158 - val_y1_mean_absolute_error: 0.1155
# Epoch 100/100
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0061 - y0_loss: 0.0032 - y1_loss: 0.0029 - y0_mean_absolute_error: 0.0443 - y1_mean_absolute_error: 0.0426 - val_loss: 0.0424 - val_y0_loss: 0.0209 - val_y1_loss: 0.0215 - val_y0_mean_absolute_error: 0.1159 - val_y1_mean_absolute_error: 0.1152

# %% [markdown]
# # 4.0 Visualize results

# %%
import matplotlib.pyplot as plt
pd.DataFrame(history.history).plot(figsize=(10,5))
plt.show()
